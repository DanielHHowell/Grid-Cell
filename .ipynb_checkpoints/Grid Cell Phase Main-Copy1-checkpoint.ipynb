# %% [markdown]
# # Grid Cell Phase Coding
#
# "Phases are in radians, coordinates are in [m] and time base is [ms]. The first data point in XYspkT corresponds with the first spike, which also corresponds with the first phase value"
#
# After changing parameters in the second cell, from the top menu click 'Cell' -> 'Run All' then scroll through
#
# (TODO: add firing map (#spikes/time), variance as lightness in meanphasemap (pi), variance weighting, amount of spikes vs. correlation, temporal separation of spikes vs. correlation, radial distribution of prediction variance, population vector prediction,
# low variance phase map?)
#
# (note whether coordinates in numpy [-y,x] or Cartesian [x,y])

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from astropy.stats import circcorrcoef
import astropy.units as u
import pycircstat

# %matplotlib inline
np.set_printoptions(suppress=True)
# %config InLineBackend.figure_format = 'retina'

# %%
dir = 'datasets/8/'

#Spatial or temporal analysis
analysis_type = 'temporal'

# %% [markdown]
# ## XYspkT
#
# XYspkT contains the X,Y coordinates of spikes. Spikes from all 30 neurons are combined in a single spike train. The X and Y columns represent the avatar's X-Y coordinate in [m] relative to the environment at the moment of the spike.
#
# XYspkT is float values, can be converted to integer with np.round(scaled_XY) as the coarse spatial analysis from the adjacency matrix only results in integer movement predictions

# %%
XYspkT = np.loadtxt(dir+'XYspkT.csv',delimiter=',')

#Aligns positions to [0,0] in the bottom-left corner
XYspkT[:,1] -= XYspkT[:,1].min()
XYspkT[:,0] -= XYspkT[:,0].min()
scaled_XY = XYspkT/2

plt.plot(scaled_XY[:,0],scaled_XY[:,1],'.')

# %% [markdown]
# ## spkT
#
# spkT contains the times of the spikes in ms

# %%
spkT = np.loadtxt(dir+'spkT.csv',delimiter=',')
print(spkT)
spkT.shape
# Out:
# [    80.    614.   1176. ... 293400. 295580. 298010.]
# (4050,)

# %% [markdown]
# ## Phase
#
# Phase is the corresponding (gamma) phase of the spikes - what phase the gamma oscillation was at them moment of spike

# %%
phase = np.loadtxt(dir+'Phase.csv',delimiter=',')
scaled_phase = phase-3.14

phase_degrees = np.degrees(phase)
sorted_phase = np.sort(phase_degrees)


#Radial histogram of phase distribution
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], polar=True)
theta = np.radians(np.arange(0,366,6))

inds = [np.where(sorted_phase<i)[0][-1] for i in np.arange(6,366,6)] #vectorize operation?
b = np.split(sorted_phase,inds)
radii = np.array([i.size/3.2 for i in b])

width = np.radians(360/60)
bars = ax.bar(theta, radii, width=width, bottom=0.0)
for theta, bar in zip(theta, bars):
    bar.set_facecolor(plt.cm.hsv(theta/6.28))
    bar.set_alpha(0.5)

plt.show()

# %%
theta = np.radians(np.arange(0,366,6))
radii.shape
# Out:
# (61,)

# %% [markdown]
# ## MeanPhaseMap
#
# MeanPhaseMap the map of gamma phases. This is a 40x43 matrix that represents the 80x86 m land of the desert, the area covered by the avatar's navigation. The lot of NaN data correspond with areas never visited. A given value at the n-th row and m-th column represents the average phase of spikes (all spikes) within that area during the entire 5 min navigation.
#
# TODO:
#
# -(time based meanphasemap of first half, traj from second)
#
# -average internode distance

# %%
def mean_phase_map(arr,bin_size):
    mpm_dict = {}
    for ybin in range(0,int(arr[:,1].max()+1),bin_size):
        mpm_dict[ybin] = {}
        for xbin in range(0,int(arr[:,0].max()+1),bin_size):
            phases = []
            mpm_dict[ybin][xbin] = []
            for spike in arr:
                if (xbin <= spike[0] <= xbin+bin_size) and (ybin <= spike[1] <= ybin+bin_size):
                    phases.append(spike[2])      
            mpm_dict[ybin][xbin] = np.nanmean(np.asarray(phases))

    return mpm_dict

mpm_arr = np.column_stack((XYspkT,scaled_phase))
mpm_dict = mean_phase_map(mpm_arr,2)

#Rotate the dataframe 90 CCW
mpm = pd.DataFrame.from_dict(mpm_dict).T
phase_df = mpm.reindex(index=mpm.index[::-1])

arena_size = phase_df.shape

plt.matshow(phase_df)

#To-do: reflect radians in bar
plt.colorbar()
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: Mean of empty slice
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## MeanVarMap
#
# MeanPhaseMap the map of gamma phases. This is a 40x43 matrix that represents the 80x86 m land of the desert, the area covered by the avatar's navigation. The lot of NaN data correspond with areas never visited. A given value at the n-th row and m-th column represents the average phase of spikes (all spikes) within that area during the entire 5 min navigation.
#
# TODO:
#
# -(time based meanphasemap of first half, traj from second)
#
# -average internode distance

# %%
def mean_var_map(arr,bin_size):
    mpm_dict = {}
    for ybin in range(0,int(arr[:,1].max()+1),bin_size):
        mpm_dict[ybin] = {}
        for xbin in range(0,int(arr[:,0].max()+1),bin_size):
            phases = []
            mpm_dict[ybin][xbin] = []
            for spike in arr:
                if (xbin <= spike[0] <= xbin+bin_size) and (ybin <= spike[1] <= ybin+bin_size):
                    phases.append(spike[2])      
            mpm_dict[ybin][xbin] = pycircstat.var(np.asarray(phases))

    return mpm_dict

mvm_arr = np.column_stack((XYspkT,scaled_phase))
mvm_dict = mean_var_map(mvm_arr,2)

#Rotate the dataframe 90 CCW
mvm = pd.DataFrame.from_dict(mvm_dict).T
var_df = mvm.reindex(index=mvm.index[::-1])

plt.matshow(var_df)

#To-do: reflect radians in bar
plt.colorbar()

# %%
var_df
# Out:
#               0             2         4         6             8         10  \
# 76           NaN           NaN  0.002652       NaN  1.110223e-16       NaN
# 74           NaN  1.110223e-16       NaN       NaN  8.780206e-02       NaN
# 72           NaN           NaN       NaN       NaN           NaN  0.857780
# 70           NaN           NaN       NaN       NaN           NaN       NaN
# 68           NaN           NaN       NaN       NaN           NaN       NaN
# 66           NaN           NaN       NaN       NaN           NaN       NaN
# 64           NaN           NaN       NaN       NaN           NaN       NaN
# 62           NaN           NaN       NaN       NaN           NaN       NaN
# 60           NaN           NaN       NaN       NaN  0.000000e+00       NaN
# 58           NaN           NaN       NaN       NaN  0.000000e+00  0.510993
# 56           NaN           NaN       NaN       NaN           NaN       NaN
# 54           NaN           NaN       NaN       NaN           NaN       NaN
# 52           NaN           NaN       NaN       NaN           NaN       NaN
# 50           NaN           NaN       NaN       NaN           NaN       NaN
# 48           NaN           NaN       NaN       NaN           NaN       NaN
# 46           NaN           NaN       NaN       NaN           NaN       NaN
# 44           NaN           NaN       NaN       NaN           NaN       NaN
# 42           NaN           NaN       NaN       NaN           NaN       NaN
# 40           NaN           NaN       NaN       NaN           NaN       NaN
# 38           NaN           NaN       NaN       NaN           NaN       NaN
# 36           NaN           NaN       NaN       NaN           NaN       NaN
# 34           NaN           NaN       NaN       NaN           NaN       NaN
# 32           NaN           NaN       NaN       NaN           NaN       NaN
# 30           NaN           NaN       NaN       NaN           NaN  0.000000
# 28           NaN           NaN       NaN       NaN           NaN       NaN
# 26           NaN           NaN       NaN       NaN  1.110223e-16       NaN
# 24           NaN           NaN       NaN       NaN           NaN       NaN
# 22           NaN           NaN       NaN       NaN  2.740263e-01       NaN
# 20           NaN           NaN       NaN       NaN  5.788235e-01       NaN
# 18           NaN           NaN       NaN  0.831051  6.201366e-03       NaN
# 16           NaN  2.109031e-01       NaN  0.683749           NaN       NaN
# 14           NaN           NaN  0.000000  0.699324           NaN       NaN
# 12           NaN  1.110223e-16  0.479201       NaN           NaN       NaN
# 10  5.984408e-01  7.446279e-02       NaN       NaN           NaN       NaN
# 8   6.551132e-01  4.516563e-01       NaN       NaN           NaN       NaN
# 6            NaN           NaN       NaN       NaN           NaN       NaN
# 4   7.163449e-01           NaN       NaN       NaN           NaN  0.169498
# 2            NaN           NaN       NaN       NaN  6.114050e-01  0.858524
# 0   1.110223e-16  5.533281e-01  0.736779  0.876182           NaN       NaN
#
#               12            14            16        18    ...     \
# 76           NaN           NaN           NaN       NaN    ...
# 74           NaN           NaN           NaN       NaN    ...
# 72           NaN           NaN           NaN       NaN    ...
# 70  8.278827e-01  0.000000e+00           NaN       NaN    ...
# 68           NaN  7.810327e-01           NaN       NaN    ...
# 66           NaN           NaN  5.658614e-01  0.000000    ...
# 64           NaN           NaN           NaN  0.609436    ...
# 62           NaN  1.110223e-16           NaN       NaN    ...
# 60           NaN           NaN           NaN       NaN    ...
# 58           NaN  0.000000e+00           NaN       NaN    ...
# 56           NaN  1.110223e-16           NaN       NaN    ...
# 54  0.000000e+00           NaN           NaN       NaN    ...
# 52  0.000000e+00           NaN           NaN       NaN    ...
# 50           NaN           NaN  1.110223e-16       NaN    ...
# 48           NaN  9.473107e-01           NaN       NaN    ...
# 46           NaN           NaN  6.861779e-01       NaN    ...
# 44           NaN           NaN  0.000000e+00       NaN    ...
# 42           NaN           NaN  8.683212e-01  0.000000    ...
# 40           NaN           NaN           NaN  0.359683    ...
# 38           NaN           NaN  7.296289e-01  0.683705    ...
# 36           NaN  1.110223e-16  6.528802e-01  0.400075    ...
# 34           NaN           NaN  4.091269e-01       NaN    ...
# 32           NaN           NaN  0.000000e+00       NaN    ...
# 30           NaN  9.020093e-01           NaN       NaN    ...
# 28  1.110223e-16           NaN           NaN       NaN    ...
# 26  6.938429e-01           NaN           NaN       NaN    ...
# 24           NaN           NaN           NaN       NaN    ...
# 22           NaN           NaN           NaN       NaN    ...
# 20           NaN           NaN           NaN       NaN    ...
# 18           NaN           NaN           NaN       NaN    ...
# 16           NaN           NaN           NaN       NaN    ...
# 14           NaN           NaN  8.178111e-01       NaN    ...
# 12           NaN           NaN  0.000000e+00  0.000000    ...
# 10           NaN           NaN  9.553612e-01       NaN    ...
# 8            NaN           NaN           NaN       NaN    ...
# 6            NaN  1.069006e-02  1.151539e-01       NaN    ...
# 4   8.817502e-01           NaN           NaN       NaN    ...
# 2            NaN           NaN           NaN       NaN    ...
# 0            NaN           NaN           NaN       NaN    ...
#
#               64        66        68        70   72            74   76  \
# 76           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 74           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 72           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 70           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 68           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 66  7.710525e-01       NaN       NaN       NaN  NaN           NaN  NaN
# 64           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 62           NaN  0.000000       NaN       NaN  NaN           NaN  NaN
# 60           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 58           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 56           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 54           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 52           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 50           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 48  0.000000e+00       NaN       NaN       NaN  NaN           NaN  NaN
# 46  8.381987e-01       NaN       NaN       NaN  NaN           NaN  NaN
# 44  0.000000e+00       NaN       NaN       NaN  NaN           NaN  NaN
# 42           NaN       NaN       NaN       NaN  NaN  1.110223e-16  NaN
# 40           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 38           NaN  0.136713       NaN  0.000000  NaN           NaN  NaN
# 36           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 34           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 32           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 30           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 28           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 26           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 24           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 22           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 20           NaN       NaN       NaN       NaN  NaN           NaN  NaN
# 18  1.110223e-16       NaN       NaN       NaN  NaN           NaN  NaN
# 16           NaN  0.641433       NaN       NaN  NaN           NaN  NaN
# 14           NaN       NaN       NaN  0.000000  NaN           NaN  NaN
# 12           NaN       NaN       NaN       NaN  0.0           NaN  NaN
# 10  0.000000e+00       NaN       NaN       NaN  NaN           NaN  NaN
# 8   3.787508e-01  0.552135       NaN       NaN  NaN           NaN  0.0
# 6   0.000000e+00       NaN  0.000000  0.529458  NaN           NaN  0.0
# 4            NaN       NaN  0.009863       NaN  0.0  2.310505e-01  0.0
# 2            NaN       NaN       NaN  0.107687  0.0           NaN  0.0
# 0            NaN       NaN       NaN       NaN  NaN           NaN  NaN
#
#           78            80        82
# 76       NaN           NaN       NaN
# 74       NaN           NaN       NaN
# 72       NaN           NaN       NaN
# 70       NaN           NaN       NaN
# 68       NaN           NaN       NaN
# 66       NaN           NaN       NaN
# 64       NaN           NaN       NaN
# 62       NaN           NaN       NaN
# 60       NaN           NaN       NaN
# 58       NaN           NaN       NaN
# 56       NaN           NaN       NaN
# 54       NaN           NaN       NaN
# 52       NaN           NaN       NaN
# 50       NaN           NaN       NaN
# 48       NaN           NaN       NaN
# 46       NaN           NaN       NaN
# 44       NaN           NaN       NaN
# 42       NaN           NaN       NaN
# 40       NaN           NaN       NaN
# 38       NaN           NaN       NaN
# 36       NaN           NaN       NaN
# 34       NaN           NaN       NaN
# 32       NaN           NaN       NaN
# 30       NaN           NaN       NaN
# 28       NaN           NaN       NaN
# 26       NaN           NaN       NaN
# 24       NaN           NaN       NaN
# 22       NaN           NaN       NaN
# 20       NaN           NaN       NaN
# 18       NaN           NaN       NaN
# 16       NaN           NaN       NaN
# 14       NaN           NaN       NaN
# 12       NaN           NaN       NaN
# 10       NaN           NaN       NaN
# 8        NaN  1.110223e-16       NaN
# 6        NaN           NaN  0.627122
# 4        NaN           NaN  0.000000
# 2   0.761057  6.254454e-01       NaN
# 0        NaN           NaN       NaN
#
# [39 rows x 42 columns]

# %% [markdown]
# ## xyPos
# xyPos is the trajectory traveled by the avatar. Each row is an X-Y data pair in [m] sampled in every ms. It is the biggest file because of the density of points. You can down-sample it to make it more manageable.

# %%
xyPos = np.loadtxt(dir+'xyPos.csv',delimiter=',')[::25]
xyPos[:,1]-= xyPos[:,1].min()
xyPos[:,0]-= xyPos[:,0].min()
print(xyPos)

#Trajectory overlaid with XYspkT
plt.plot(xyPos[:,0],xyPos[:,1], color='b')
plt.plot(XYspkT[:,0],XYspkT[:,1], '.', color='r', markersize=6)
# Out:
# [[31.3563 35.2696]
#  [31.3563 35.2696]
#  [31.3563 35.2696]
#  ...
#  [58.159  42.3208]
#  [58.263  42.2514]
#  [58.364  42.1784]]

# %% [markdown]
# ## MeanPhaseMap DataFrame

# %%
phase_df
# Out:
#           0         2         4         6         8         10        12  \
# 76       NaN       NaN  1.472350       NaN -2.432750       NaN       NaN
# 74       NaN -0.145800       NaN       NaN  2.028567       NaN       NaN
# 72       NaN       NaN       NaN       NaN       NaN  1.086400       NaN
# 70       NaN       NaN       NaN       NaN       NaN       NaN -0.239228
# 68       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 66       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 64       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 62       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 60       NaN       NaN       NaN       NaN  2.764700       NaN       NaN
# 58       NaN       NaN       NaN       NaN -2.557800  0.055600       NaN
# 56       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 54       NaN       NaN       NaN       NaN       NaN       NaN  2.346900
# 52       NaN       NaN       NaN       NaN       NaN       NaN  1.666200
# 50       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN -0.236900       NaN
# 28       NaN       NaN       NaN       NaN       NaN       NaN  1.475500
# 26       NaN       NaN       NaN       NaN -3.123914       NaN  0.658050
# 24       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN       NaN -0.269340       NaN       NaN
# 20       NaN       NaN       NaN       NaN -0.161400       NaN       NaN
# 18       NaN       NaN       NaN -0.402418 -2.200020       NaN       NaN
# 16       NaN  0.399467       NaN  0.881925       NaN       NaN       NaN
# 14       NaN       NaN -1.938100 -0.058200       NaN       NaN       NaN
# 12       NaN  1.339300 -0.236915       NaN       NaN       NaN       NaN
# 10  1.032050 -0.577280       NaN       NaN       NaN       NaN       NaN
# 8  -0.221657  0.420905       NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4   1.004100       NaN       NaN       NaN       NaN  0.231433 -0.022157
# 2        NaN       NaN       NaN       NaN -0.684100 -0.129590       NaN
# 0   2.393100  0.623720 -0.316335  0.062820       NaN       NaN       NaN
#
#           14        16        18    ...           64        66        68  \
# 76       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 74       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 72       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 70 -1.479000       NaN       NaN    ...          NaN       NaN       NaN
# 68  0.484056       NaN       NaN    ...          NaN       NaN       NaN
# 66       NaN -1.390063  0.479800    ...    -0.994200       NaN       NaN
# 64       NaN       NaN  1.334929    ...          NaN       NaN       NaN
# 62 -1.302800       NaN       NaN    ...          NaN  0.706200       NaN
# 60       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 58 -2.124100       NaN       NaN    ...          NaN       NaN       NaN
# 56  2.931000       NaN       NaN    ...          NaN       NaN       NaN
# 54       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 52       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 50       NaN  3.085600       NaN    ...          NaN       NaN       NaN
# 48 -1.464510       NaN       NaN    ...     0.975900       NaN       NaN
# 46       NaN -0.952435       NaN    ...     0.153502       NaN       NaN
# 44       NaN -2.181420       NaN    ...     2.317100       NaN       NaN
# 42       NaN -0.323440  2.507000    ...          NaN       NaN       NaN
# 40       NaN       NaN -1.741727    ...          NaN       NaN       NaN
# 38       NaN  0.134346  0.030127    ...          NaN -0.452143       NaN
# 36 -0.323700 -1.034850  1.449118    ...          NaN       NaN       NaN
# 34       NaN -0.157267       NaN    ...          NaN       NaN       NaN
# 32       NaN -1.306600       NaN    ...          NaN       NaN       NaN
# 30 -0.372408       NaN       NaN    ...          NaN       NaN       NaN
# 28       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 26       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 24       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 22       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 20       NaN       NaN       NaN    ...          NaN       NaN       NaN
# 18       NaN       NaN       NaN    ...    -3.007690       NaN       NaN
# 16       NaN       NaN       NaN    ...          NaN -1.758269       NaN
# 14       NaN -0.612876       NaN    ...          NaN       NaN       NaN
# 12       NaN -3.106093  0.291000    ...          NaN       NaN       NaN
# 10       NaN  0.732250       NaN    ...    -2.671260       NaN       NaN
# 8        NaN       NaN       NaN    ...    -1.103400  0.421633       NaN
# 6  -0.186650  1.642067       NaN    ...     2.690300       NaN -0.818800
# 4        NaN       NaN       NaN    ...          NaN       NaN  0.262233
# 2        NaN       NaN       NaN    ...          NaN       NaN       NaN
# 0        NaN       NaN       NaN    ...          NaN       NaN       NaN
#
#          70      72      74      76        78       80        82
# 76      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 74      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 72      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 70      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 68      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 66      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 64      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 62      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 60      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 58      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 56      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 54      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 52      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 50      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 48      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 46      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 44      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 42      NaN     NaN  3.1014     NaN       NaN      NaN       NaN
# 40      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 38 -1.97780     NaN     NaN     NaN       NaN      NaN       NaN
# 36      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 34      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 32      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 30      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 28      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 26      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 24      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 22      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 20      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 18      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 16      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 14 -0.90010     NaN     NaN     NaN       NaN      NaN       NaN
# 12      NaN  1.8355     NaN     NaN       NaN      NaN       NaN
# 10      NaN     NaN     NaN     NaN       NaN      NaN       NaN
# 8       NaN     NaN     NaN -0.1130       NaN -2.90563       NaN
# 6   1.97640     NaN     NaN  2.0141       NaN      NaN -0.502503
# 4       NaN  0.8899  0.6114 -1.4101       NaN      NaN  0.801400
# 2   0.92522  2.9275     NaN  0.1289 -0.696445 -1.56418       NaN
# 0       NaN     NaN     NaN     NaN       NaN      NaN       NaN
#
# [39 rows x 42 columns]

# %%
#A padded phase map for use in edge-cases for extracting the 5x5 adjacency matrix below
padded_phase_map = np.pad(phase_df,pad_width=2,mode='constant',constant_values=np.nan)
padded_phase_df = pd.DataFrame(data=padded_phase_map)
padded_phase_df.shape
# Out:
# (43, 46)

# %% [markdown]
# ### Adjacency Function
#
# Adjacent spikes returns the best matching MeanPhaseMap location for the next 6 spikes phases, adjacent matrix returns a 5x5 array to analyze a region of space adjacent to a target location within the MeanPhaseMap, then finds
# the x and y difference from the center to cell to the cell with the cloest matching value (of phase).
#
# example return array:
#
#        [ 3.0844,     nan, -1.5684,     nan,     nan],
#
#        [ 3.0844,     nan,     nan, -1.6837, -1.5763],
#
#        [    nan,     nan,     nan,     nan, -1.5088],
#
#        [-2.8458,     nan,     nan,     nan, -2.5082],
#
#        [-2.8458,     nan,     nan,     nan,     nan]

# %%
def adjacent_matrix(cell, phase):
    """Determines change vector from central cell to cell
    nearest in value in 5x5 IN FORM **[X,Y]** """        
    x = int(cell[0])
    y = int(cell[1])
    y_size = arena_size[0]-1
    a = padded_phase_df.iloc[y_size-y:y_size-y+5,x:x+5]

    try:
        nearest = np.nanargmin(np.abs(a-phase))
        loc = [(nearest%5)-2,2-(nearest//5)]

        #Rounding down to the nearest bin, adding 0.5 to point to center of bin        
        xp = x+loc[0]+0.5
        yp = y+loc[1]+0.5    
        return[xp - cell[0],yp - cell[1]]

    except:
        return [0,0]    


def adjacent_spikes(spikes, phase):
    """Get location of spike with most similar phase"""
    y_size = arena_size[0] - 1
    phases = []
    vars = []
    for i in spikes:
        x = int(i[0])
        y = int(i[1])
        phases.append(phase_df.iloc[y_size - y, x])
        vars.append(var_df.iloc[y_size - y, x])
    phases = np.asarray(phases)
    vars = np.asarray(vars)
    diffs = np.abs(phases - phase)*vars
    
    try:
        nearest = np.nanargmin(np.abs(phases - phase))
    except:
        nearest = 0

    try:
        #Rounding down to the nearest bin, adding 0.5 to point to center of bin
        x = int(spikes[nearest][0])+0.5 
        y = int(spikes[nearest][1])+0.5
        return [x - spikes[0, 0], y - spikes[0, 1]]

    except:
        return [0.0, 0.0]
    
    
#Tests:
#print(adjacent_matrix([3,0.5],-1.5))
#adjacent_spikes(combined[10:16,1:3],combined[10,4])

# %% [markdown]
# ## Combined Position, Time and Phase DataFrame
#
# X,Y position, change in distance, time and phase data sorted by trajectory from the Time column in a dataframe

# %%
unsorted = np.column_stack((spkT,scaled_XY,scaled_phase))
sorted = unsorted[unsorted[:,0].argsort()]

#Calculate movement magnitudes
xdif = np.append(sorted[1:,1],0)-np.append(sorted[:-1,1],0)
ydif = np.append(sorted[1:,2],0)-np.append(sorted[:-1,2],0)

#Drop rows with movements below threshold
move_thresh = 0.01

raw = np.column_stack((sorted,xdif,ydif))
print(raw)
movement  = raw[np.any(abs(raw[:,4:]) >= move_thresh, axis=1)]

#Recalculate movement magnitudes
xdif = np.append(movement[1:,1],0)-np.append(movement[:-1,1],0)
ydif = np.append(movement[1:,2],0)-np.append(movement[:-1,2],0)
next_phase = np.insert(movement[1:,3],-1, 0)

combined = np.column_stack((movement[:,:4],next_phase,xdif,ydif))
print(combined)
# Out:
# [[  1451.            16.2907        18.447545       1.8396
#        0.12695        0.0936745]
#  [  1834.            16.41765       18.5412195     -0.5697
#        0.12775        0.0782705]
#  [  1901.            16.5454        18.61949       -2.49237
#        0.41165        0.286165 ]
#  ...
#  [298070.            28.6095        21.37515        2.2143
#        0.2875        -0.11175  ]
#  [298190.            28.897         21.2634        -0.388
#        0.194         -0.11115  ]
#  [298280.            29.091         21.15225        1.8195
#        0.             0.       ]]
# [[  1451.            16.2907        18.447545  ...     -0.5697
#        0.12695        0.0936745]
#  [  1834.            16.41765       18.5412195 ...     -2.49237
#        0.12775        0.0782705]
#  [  1901.            16.5454        18.61949   ...     -1.5152
#        0.41165        0.286165 ]
#  ...
#  [298010.            28.477         21.4085    ...      2.2143
#        0.1325        -0.03335  ]
#  [298070.            28.6095        21.37515   ...      0.
#        0.2875        -0.11175  ]
#  [298190.            28.897         21.2634    ...     -0.388
#        0.             0.       ]]

# %%
# Spatial Analysis
if analysis_type == 'spatial':
    predicted = [adjacent_matrix([i[1],i[2]],i[4]) for i in combined]
    predicted_movement = np.asarray(predicted)

# Temporal Analysis    
if analysis_type == 'temporal':
    predicted = [adjacent_spikes(combined[i:i+7,1:3],combined[i,4]) for i in range(len(combined))]
    predicted_movement = np.asarray(predicted)
    
all=np.column_stack((combined,predicted_movement))
df = pd.DataFrame(data=all, columns=['Time','X','Y','Phase','Next Phase','Xdif','Ydif','Xdif Predicted', 'Ydif Predicted'])

df
# Out:
#          Time          X          Y    Phase  Next Phase      Xdif      Ydif  \
# 0      1451.0  16.290700  18.447545  1.83960    -0.56970  0.126950  0.093674
# 1      1834.0  16.417650  18.541220 -0.56970    -2.49237  0.127750  0.078270
# 2      1901.0  16.545400  18.619490 -2.49237    -1.51520  0.411650  0.286165
# 3      2117.0  16.957050  18.905655 -1.51520    -1.80140  0.067750  0.049390
# 4      2150.0  17.024800  18.955045 -1.80140    -0.03330  0.099850  0.072765
# 5      2200.0  17.124650  19.027810 -0.03330    -1.01800  0.068450  0.049990
# 6      2234.0  17.193100  19.077800 -1.01800    -2.15843  0.168200  0.120300
# 7      2317.0  17.361300  19.198100 -2.15843     0.56460  0.291150  0.156250
# 8      2450.0  17.652450  19.354350  0.56460     1.22060  0.356800  0.108650
# 9      2600.0  18.009250  19.463000  1.22060     0.15610  0.073700  0.012650
# 10     2630.0  18.082950  19.475650  0.15610    -1.36630  0.787800 -0.057600
# 11     2950.0  18.870750  19.418050 -1.36630     1.27950  0.443800 -0.204900
# 12     3147.0  19.314550  19.213150  1.27950    -0.48680  1.601150 -1.214450
# 13     3956.0  20.915700  17.998700 -0.48680    -1.34370  0.220800 -0.113700
# 14     4056.0  21.136500  17.885000 -1.34370    -1.30770  2.298050 -1.309750
# 15     5106.0  23.434550  16.575250 -1.30770    -0.71310  0.714300 -0.504600
# 16     5573.0  24.148850  16.070650 -0.71310    -2.89496  0.128500  0.238850
# 17     9690.0  24.277350  16.309500 -2.89496    -0.34450  3.066150  6.518700
# 18    12657.0  27.343500  22.828200 -0.34450     2.34110  0.488000  0.902800
# 19    13069.0  27.831500  23.731000  2.34110     1.32920  0.842000  1.947000
# 20    13924.0  28.673500  25.678000  1.32920     1.05830  0.039500  0.072500
# 21    13957.0  28.713000  25.750500  1.05830    -1.58800  0.364000  0.671500
# 22    14264.0  29.077000  26.422000 -1.58800     1.87740  1.050000  1.936500
# 23    15149.0  30.127000  28.358500  1.87740     1.17320  0.714000  1.832000
# 24    15933.0  30.841000  30.190500  1.17320     0.96150 -0.015500  0.182500
# 25    16008.0  30.825500  30.373000  0.96150     0.99000 -0.847500  1.291000
# 26    16649.0  29.978000  31.664000  0.99000     0.37540 -0.071500  0.041000
# 27    16682.0  29.906500  31.705000  0.37540    -0.09440 -0.073500  0.038500
# 28    16715.0  29.833000  31.743500 -0.09440    -1.12750 -0.076000  0.035000
# 29    16749.0  29.757000  31.778500 -1.12750     1.46030 -0.194000  0.070000
# ..        ...        ...        ...      ...         ...       ...       ...
# 559  258590.0  25.111600  16.973800  1.60190     0.33180 -1.704150  4.831900
# 560  260630.0  23.407450  21.805700  0.33180    -1.01230 -1.126350  2.372300
# 561  261690.0  22.281100  24.178000 -1.01230     1.14000 -1.004600  2.227500
# 562  262680.0  21.276500  26.405500  1.14000     0.03150 -2.081300  5.455500
# 563  265010.0  19.195200  31.861000  0.03150    -3.03617 -0.017050  0.042000
# 564  265030.0  19.178150  31.903000 -3.03617    -1.59590 -0.973400  2.771500
# 565  268560.0  18.204750  34.674500 -1.59590    -2.81254  2.428920 -4.525000
# 566  270890.0  20.633670  30.149500 -2.81254    -1.15810  2.079630 -6.050500
# 567  273450.0  22.713300  24.099000 -1.15810     2.96960  0.058050 -0.321000
# 568  273580.0  22.771350  23.778000  2.96960     0.06630  0.884050 -3.442400
# 569  275000.0  23.655400  20.335600  0.06630     2.57540  0.487600 -1.293250
# 570  275560.0  24.143000  19.042350  2.57540    -0.60050  0.540450 -2.504300
# 571  278410.0  24.683450  16.538050 -0.60050     0.59050 -3.913100 -2.573550
# 572  280790.0  20.770350  13.964500  0.59050     2.91900 -0.693070 -0.456000
# 573  281120.0  20.077280  13.508500  2.91900     1.71870 -2.008830 -1.321000
# 574  282090.0  18.068450  12.187500  1.71870    -2.87237 -4.945950 -0.525500
# 575  284480.0  13.122500  11.662000 -2.87237     1.91320 -2.180500  3.916350
# 576  286260.0  10.942000  15.578350  1.91320     0.15810 -1.635500  2.936681
# 577  287610.0   9.306500  18.515031  0.15810     3.04400 -0.151000  0.271604
# 578  287740.0   9.155500  18.786635  3.04400     1.74160 -0.103000  1.132865
# 579  289270.0   9.052500  19.919500  1.74160    -2.82799  5.178000  0.089500
# 580  292260.0  14.230500  20.009000 -2.82799    -1.78860  2.925200  0.445350
# 581  293450.0  17.155700  20.454350 -1.78860     3.13680  2.949815  0.247350
# 582  294630.0  20.105515  20.701700  3.13680     0.49050  1.633435  0.215700
# 583  295290.0  21.738950  20.917400  0.49050     1.43320  1.880750  0.248400
# 584  296050.0  23.619700  21.165800  1.43320     0.65620  4.788800  0.255800
# 585  297980.0  28.408500  21.421600  0.65620    -0.64290  0.068500 -0.013100
# 586  298010.0  28.477000  21.408500 -0.64290     2.21430  0.132500 -0.033350
# 587  298070.0  28.609500  21.375150  2.21430     0.00000  0.287500 -0.111750
# 588  298190.0  28.897000  21.263400 -0.38800    -0.38800  0.000000  0.000000
#
#      Xdif Predicted  Ydif Predicted
# 0          1.209300        1.052455
# 1          1.082350       -0.041220
# 2          0.954600       -0.119490
# 3          0.542950       -0.405655
# 4          1.475200        0.544955
# 5          0.375350        0.472190
# 6          0.306900        0.422200
# 7          1.138700        0.301900
# 8          1.847550        0.145650
# 9          0.490750        0.037000
# 10         3.417050       -1.975650
# 11         0.629250        0.081950
# 12         1.185450       -1.713150
# 13         0.584300       -0.498700
# 14         0.363500       -0.385000
# 15         1.065450       -0.075250
# 16         5.351150       10.429350
# 17         0.222650        0.190500
# 18         0.156500        0.671800
# 19         0.668500        1.769000
# 20         1.826500        4.822000
# 21         0.787000        0.749500
# 22         1.423000        2.078000
# 23         0.373000        2.141500
# 24        -0.341000        0.309500
# 25        -0.325500        0.127000
# 26        -0.478000       -0.164000
# 27        -0.406500       -0.205000
# 28        -2.333000       -0.243500
# 29        -1.257000       -0.278500
# ..              ...             ...
# 559        0.388400       -0.473800
# 560       -0.907450        2.694300
# 561       -0.781100        2.322000
# 562        1.223500       -1.905500
# 563        1.304800       -1.361000
# 564       -0.678150        2.597000
# 565        2.295250       -4.174500
# 566        1.866330       -5.649500
# 567       -0.213300       -0.599000
# 568        0.728650       -3.278000
# 569       -3.155400       -6.835600
# 570       -5.643000       -6.542350
# 571       -0.183450       -0.038050
# 572      -10.270350        1.535500
# 573       -9.577280        1.991500
# 574       -4.568450       -0.687500
# 575       -2.622500        3.838000
# 576       -1.442000        3.921650
# 577        0.193500       -0.015031
# 578        0.344500       -0.286635
# 579        5.447500        0.580500
# 580        3.269500        0.491000
# 581        6.344300        1.045650
# 582        1.394485       -0.201700
# 583        1.761050        0.582600
# 584        4.880300        0.334200
# 585        0.091500        0.078400
# 586        0.023000        0.091500
# 587       -0.109500        0.124850
# 588       -0.397000        0.236600
#
# [589 rows x 9 columns]

# %%
plt.rcParams['figure.figsize'] = [20, 15]
ax = plt.subplot()
plt.plot(xyPos[:,0]/2, xyPos[:,1]/2, color='b')
plt.plot(scaled_XY[:,0], scaled_XY[:,1], '.', color='r', markersize=6)
for index, row in df.iterrows():
    # if (row['Xdif Predicted']>0) or (row['Ydif Predicted']>0):
    plt.arrow(row['X'], row['Y'], row['Xdif Predicted'], row['Ydif Predicted'],
                head_width=0.2, color='black')

ax.set_xticks(np.arange(scaled_XY[:,0].min()-1,scaled_XY[:,0].max()+2))
ax.set_yticks(np.arange(scaled_XY[:,1].min()-1,scaled_XY[:,1].max()+1))
ax.grid()

# %% [markdown]
# ## Vector Angles
#
# Calculates the angle between each movements observed and predicted vector angle to store in a list for use
# in the correlation figures

# %%
#Determines the angle between the horizontal axis (+1 x, +0 y) and the current vector, returns [observed,predicted]
def abs_vector_angles(arr):
    
    obs_angles = []
    pred_angles = []
    
    for i in range(len(arr)-1):
        p0 = [all[i,1]+1,all[i,2]]
        p1 = [all[i,1],all[i,2]]
        p2 = [all[i+1,1],all[i+1,2]]
        v0 = np.array(p0) - np.array(p1)
        v1 = np.array(p2) - np.array(p1)
        atan = np.math.atan2(np.linalg.det([v0,v1]),np.dot(v0,v1))
        if np.degrees(atan)<0:
            obs_angles.append(360+np.degrees(atan))
        else:
            obs_angles.append(np.degrees(atan))
        
    for i in range(len(arr)-1):
        p0 = [all[i,1]+1,all[i,2]]
        p1 = [all[i,1],all[i,2]]
        p2 = [all[i,1]+all[i,7],all[i,2]+all[i,8]]
        v0 = np.array(p0) - np.array(p1)
        v1 = np.array(p2) - np.array(p1)
        atan = np.math.atan2(np.linalg.det([v0,v1]),np.dot(v0,v1))
        if np.degrees(atan)<0:
            pred_angles.append(360+np.degrees(atan))
        else:
            pred_angles.append(np.degrees(atan))
        
    return(list(zip(obs_angles,pred_angles)))

# %%
angles = np.asarray(abs_vector_angles(all))

print('Linear r correlation : ' + str(pearsonr(angles[:,0],angles[:,1])[0]))
print('Circular r correlation: ' + str(pycircstat.corrcc(np.radians(angles[:,0]),np.radians(angles[:,1]))))
# Out:
# Linear r correlation : 0.517169355735668
# Circular r correlation: 0.6444920562567534

# %%
np.radians(angles[:500])
# Out:
# array([[0.63570231, 0.71616241],
#        [0.54969448, 6.24512037],
#        [0.60747416, 6.15866013],
#        [0.6299275 , 5.64152262],
#        [0.62975733, 0.35386168],
#        [0.63078263, 0.89916488],
#        [0.62086785, 0.9422395 ],
#        [0.49254756, 0.2591643 ],
#        [0.29559139, 0.07867142],
#        [0.1699854 , 0.07525243],
#        [6.21020017, 5.75896884],
#        [5.85064894, 0.12950551],
#        [5.63427519, 5.31770596],
#        [5.80765279, 5.57666287],
#        [5.76516227, 5.46907092],
#        [5.66815968, 6.21267496],
#        [1.07721705, 1.09673507],
#        [1.13113882, 0.70773789],
#        [1.07524465, 1.34192205],
#        [1.16262383, 1.20948814],
#        [1.07193293, 1.20871167],
#        [1.07406179, 0.76099689],
#        [1.07394946, 0.97034943],
#        [1.19916769, 1.39834934],
#        [1.6555245 , 2.40458098],
#        [2.15170494, 2.76958992],
#        [2.62094165, 3.47210394],
#        [2.65907936, 3.60867836],
#        [2.7100196 , 3.24558817],
#        [2.79530715, 3.35962975],
#        [2.88590359, 3.30894146],
#        [2.99092141, 3.52484   ],
#        [3.351536  , 3.68222357],
#        [3.55045425, 5.76529233],
#        [3.55043907, 3.32256933],
#        [3.55009794, 0.90664918],
#        [3.55135058, 4.08122012],
#        [3.54964232, 2.35550721],
#        [3.54980144, 4.31089749],
#        [3.55365563, 5.01696155],
#        [3.55025643, 5.20394812],
#        [3.54922416, 3.61110391],
#        [3.54998204, 3.68600512],
#        [3.55148045, 3.74486125],
#        [3.55124594, 3.61950578],
#        [3.67028999, 3.76481526],
#        [3.66415836, 3.49863153],
#        [3.50239748, 3.86744338],
#        [3.61242166, 3.47101293],
#        [3.66530275, 2.71624969],
#        [3.66540943, 3.87013242],
#        [3.66526465, 3.77235612],
#        [3.66529483, 3.54325276],
#        [3.606627  , 3.65274031],
#        [5.8512976 , 0.38360164],
#        [5.92202843, 6.22995428],
#        [6.27849104, 6.26969275],
#        [0.11731596, 6.26752545],
#        [0.07325833, 6.23806581],
#        [0.04768304, 6.18873817],
#        [0.04768565, 0.03021309],
#        [0.04764554, 0.17359306],
#        [0.14809283, 6.17338464],
#        [0.1424254 , 0.10848054],
#        [0.18661229, 5.974441  ],
#        [6.18175171, 6.20402004],
#        [3.72416137, 3.96853964],
#        [3.24612824, 5.46748635],
#        [3.12518852, 3.23487055],
#        [3.1079535 , 3.32917774],
#        [3.10795246, 3.7997837 ],
#        [3.10784164, 4.83814868],
#        [3.10794918, 3.69279457],
#        [3.10794416, 4.1613435 ],
#        [3.10827166, 5.12095682],
#        [3.10779258, 5.26318524],
#        [3.10804729, 2.79683147],
#        [3.10794807, 2.70667613],
#        [3.10706093, 3.04531648],
#        [3.10802318, 1.84479517],
#        [3.10798949, 1.18982965],
#        [3.10797102, 2.48807848],
#        [3.10774315, 3.09090122],
#        [3.10795379, 1.76390828],
#        [3.10797357, 3.09589761],
#        [3.10788832, 2.64263925],
#        [3.10796507, 3.09325557],
#        [3.1079489 , 0.32091057],
#        [3.23939191, 0.1593743 ],
#        [4.11459177, 4.32062523],
#        [4.51951731, 4.39996766],
#        [4.31364496, 1.8536819 ],
#        [4.25030545, 4.34020832],
#        [4.22143016, 4.115662  ],
#        [4.22154991, 4.06738972],
#        [4.21811638, 2.26151348],
#        [4.22487323, 3.98934261],
#        [4.22033992, 3.97894552],
#        [4.22179372, 4.57213937],
#        [4.22101669, 4.73719635],
#        [4.2222575 , 5.32911265],
#        [4.22150016, 5.68808605],
#        [4.22216276, 4.23878019],
#        [4.22120596, 2.40679374],
#        [4.22791105, 4.2922727 ],
#        [4.21210855, 4.64610146],
#        [4.22614635, 4.3318826 ],
#        [4.22353663, 4.36763842],
#        [4.22082208, 4.25572807],
#        [4.22157414, 1.04848852],
#        [4.22735426, 4.27423374],
#        [4.21504626, 5.61931179],
#        [4.22185299, 5.69942116],
#        [4.21789816, 4.04237386],
#        [4.22455254, 4.03004464],
#        [4.22122538, 4.4956015 ],
#        [4.22172092, 3.95475367],
#        [4.22146274, 3.90336792],
#        [4.22310596, 2.32096235],
#        [4.21596623, 4.42272393],
#        [4.22302843, 2.07740391],
#        [4.21844761, 4.48252308],
#        [4.22132208, 4.55517511],
#        [4.22029376, 4.30382689],
#        [4.21596623, 5.0251455 ],
#        [4.22349421, 4.7298151 ],
#        [4.22089592, 4.50758292],
#        [4.22149807, 4.54698733],
#        [4.22267651, 5.07971038],
#        [4.88614872, 4.71970643],
#        [5.82787493, 2.70665415],
#        [5.9653873 , 0.33715786],
#        [6.03224369, 1.30251382],
#        [6.16273941, 0.47081517],
#        [6.25213938, 0.64193654],
#        [0.04214371, 0.70721683],
#        [0.1462904 , 0.33438146],
#        [0.22402365, 1.14099682],
#        [0.26520712, 0.37386931],
#        [0.42276889, 1.36056961],
#        [0.55859932, 2.64765128],
#        [0.5562584 , 0.64974912],
#        [0.5569401 , 0.16560415],
#        [0.55620085, 0.69693962],
#        [0.55838578, 0.36853512],
#        [0.55583047, 3.90395824],
#        [0.55723622, 1.21319616],
#        [0.5556117 , 0.92522053],
#        [0.55630428, 2.95111362],
#        [0.55729554, 1.13964766],
#        [0.55682492, 1.22192064],
#        [0.55651365, 1.41740308],
#        [0.55616623, 1.92638012],
#        [0.55531202, 0.52832412],
#        [0.55779778, 0.52555071],
#        [0.55639456, 0.71690239],
#        [0.55479223, 3.94078305],
#        [0.55754111, 0.79179585],
#        [0.55549374, 0.44301284],
#        [0.55651695, 0.83177838],
#        [0.55717364, 3.74203243],
#        [0.55637286, 1.75953409],
#        [0.55603675, 0.27275336],
#        [0.55744608, 0.55584292],
#        [0.55657335, 0.52170732],
#        [0.55640756, 0.68859852],
#        [0.5567539 , 0.22307636],
#        [0.55661346, 0.55236247],
#        [0.55645058, 0.54816341],
#        [0.71901971, 0.80172379],
#        [0.70337228, 0.68349234],
#        [0.57996346, 0.62512306],
#        [0.57830622, 4.24011076],
#        [0.58090642, 0.50482634],
#        [0.57876758, 0.50249494],
#        [0.57915132, 0.89132718],
#        [1.87686164, 1.10986242],
#        [1.49780011, 0.37580913],
#        [1.36757195, 1.41030177],
#        [1.36726514, 1.29145298],
#        [1.36730176, 1.52353636],
#        [1.36725816, 1.27408208],
#        [1.36723686, 1.97867386],
#        [1.36735984, 1.82038484],
#        [1.36726937, 1.24749532],
#        [1.36727339, 2.03489212],
#        [1.19653732, 1.23137688],
#        [1.18185467, 0.96260569],
#        [1.18297479, 1.18138638],
#        [1.18200041, 1.4400041 ],
#        [1.18194391, 1.06039635],
#        [1.18198527, 1.1960404 ],
#        [1.18217105, 1.15259627],
#        [1.18191635, 1.15159338],
#        [1.1818173 , 0.79882901],
#        [1.16504724, 4.97337847],
#        [6.25022043, 6.24506514],
#        [6.1972654 , 4.49212676],
#        [5.91934093, 4.33385728],
#        [5.08492692, 5.13314495],
#        [4.11879792, 4.20106392],
#        [4.19261024, 4.2361092 ],
#        [4.23723051, 4.19172272],
#        [4.21966621, 4.33143645],
#        [6.11477463, 5.58632888],
#        [5.45824667, 4.65571216],
#        [5.28242944, 5.47133256],
#        [5.28712336, 5.49366398],
#        [5.29505016, 5.49052576],
#        [5.42221095, 5.51259924],
#        [5.4988156 , 5.52894545],
#        [5.49862117, 2.28547662],
#        [5.49829935, 5.54569478],
#        [5.50197122, 5.56172673],
#        [5.49994697, 5.56615483],
#        [5.49863174, 5.5772475 ],
#        [5.49778714, 5.6181594 ],
#        [5.49947064, 5.32241363],
#        [5.49807132, 5.50653768],
#        [5.49907084, 0.14322312],
#        [5.49541185, 5.50324871],
#        [5.44706556, 5.30563533],
#        [5.54552326, 5.78961014],
#        [5.54528315, 5.56071831],
#        [5.54537025, 5.59303662],
#        [5.54816465, 5.60299994],
#        [5.54440305, 5.36523561],
#        [5.54531231, 5.84877249],
#        [5.54530945, 5.86988968],
#        [5.50411297, 5.68571734],
#        [5.02044176, 5.14718816],
#        [4.536658  , 4.81598396],
#        [3.65819336, 3.61693564],
#        [2.95005354, 3.12283648],
#        [2.74307021, 2.59301558],
#        [2.6845239 , 3.46939915],
#        [2.68208581, 2.51157676],
#        [2.68322204, 2.28757388],
#        [2.68266436, 2.61587251],
#        [2.68261583, 2.64281349],
#        [2.68232836, 3.05510375],
#        [2.56567678, 2.60588363],
#        [2.5433561 , 2.52044984],
#        [2.54329336, 3.21268032],
#        [2.54331361, 2.50956187],
#        [2.54425304, 2.44296511],
#        [2.54343404, 2.91314836],
#        [2.54327515, 2.46974964],
#        [2.5435383 , 2.84199098],
#        [2.39202066, 2.40533843],
#        [2.33872902, 1.98588666],
#        [2.33534905, 1.97871332],
#        [2.33489484, 2.43260326],
#        [2.33548481, 3.04876444],
#        [2.33552971, 2.5852307 ],
#        [2.33129238, 2.45117154],
#        [2.33526943, 2.8793902 ],
#        [2.33586632, 4.40209969],
#        [2.33507734, 1.21923967],
#        [2.33797788, 2.68032958],
#        [2.44440737, 2.68880935],
#        [2.52090658, 2.48444972],
#        [2.5202468 , 2.44892499],
#        [2.52026729, 2.68783253],
#        [2.51908759, 2.70773902],
#        [2.52043362, 3.83369334],
#        [2.52231404, 1.95311429],
#        [2.52006603, 2.89576945],
#        [2.40798602, 1.87432673],
#        [1.15537297, 1.91010871],
#        [1.14011984, 1.91939111],
#        [1.74586743, 3.65296449],
#        [1.895048  , 1.95331203],
#        [1.90612071, 2.64705155],
#        [2.03782088, 2.10291551],
#        [2.16185177, 1.63118477],
#        [2.04338114, 1.88676894],
#        [2.03815794, 1.64751083],
#        [2.0925743 , 2.07883983],
#        [2.02675814, 1.9718408 ],
#        [0.88906877, 0.80420651],
#        [0.38293238, 0.39035966],
#        [6.10307586, 0.02537646],
#        [5.5017659 , 5.28548105],
#        [5.48112202, 5.39865956],
#        [5.48035568, 4.56586398],
#        [5.48112202, 5.37707215],
#        [5.48016782, 2.64913161],
#        [5.48078724, 6.00652185],
#        [5.48007107, 5.42634928],
#        [5.48083961, 0.27949002],
#        [5.47981368, 0.33418831],
#        [5.48354309, 5.34895233],
#        [5.47651376, 5.31638805],
#        [5.48112202, 5.28554439],
#        [5.48074334, 5.26429715],
#        [5.47960733, 4.91105358],
#        [5.48240374, 2.73155719],
#        [5.48018896, 5.42816178],
#        [5.48023109, 5.4154267 ],
#        [5.48106629, 4.1520291 ],
#        [5.48054747, 2.62787799],
#        [5.48112202, 5.4480969 ],
#        [5.4799319 , 2.48313068],
#        [5.4793135 , 0.40414884],
#        [5.48160733, 5.42973478],
#        [5.48069479, 5.41955327],
#        [5.47829101, 5.33033373],
#        [5.48877838, 5.49285476],
#        [5.47930875, 5.48565984],
#        [5.48027799, 5.48606282],
#        [5.48027006, 5.49906029],
#        [5.48016782, 5.52163028],
#        [5.48028515, 5.40114161],
#        [5.48029184, 5.44081003],
#        [5.48019571, 5.61020534],
#        [5.41116384, 5.21810783],
#        [5.39934194, 5.43269221],
#        [5.41384694, 5.27184067],
#        [5.26128876, 5.25735242],
#        [4.66497928, 3.08379266],
#        [3.18333759, 3.25894715],
#        [2.58824086, 2.70391861],
#        [2.58773967, 3.15288697],
#        [2.58833341, 4.10166302],
#        [2.58778405, 2.52102289],
#        [2.59242465, 2.80958579],
#        [2.59221817, 2.49088926],
#        [2.5878865 , 2.69590284],
#        [2.58814866, 2.48095337],
#        [2.58817949, 2.59293854],
#        [2.58805699, 3.23672576],
#        [2.58838838, 4.07622157],
#        [2.58892017, 0.97467709],
#        [2.43511412, 2.12573393],
#        [2.44426653, 2.41033016],
#        [2.41918057, 2.38064639],
#        [1.20698405, 5.74041194],
#        [1.23412151, 5.64915437],
#        [1.65516567, 1.77358327],
#        [1.75255187, 1.86915298],
#        [1.75249155, 2.42552062],
#        [1.75669576, 1.73620895],
#        [1.74812538, 1.76583887],
#        [1.74833307, 1.57630535],
#        [1.75274176, 1.59227041],
#        [1.75278573, 1.78003178],
#        [1.75258352, 1.66569118],
#        [1.72769674, 1.46968011],
#        [0.86778624, 0.09654836],
#        [0.1532602 , 5.58686189],
#        [5.71161182, 5.75457037],
#        [5.46697862, 5.23281587],
#        [5.40873756, 5.63493209],
#        [5.4223006 , 5.64355078],
#        [5.41734362, 4.32628826],
#        [5.41853419, 5.72979135],
#        [5.41770629, 5.04369206],
#        [5.41905895, 5.77397035],
#        [5.4187802 , 4.10479364],
#        [5.41711156, 6.05179845],
#        [5.42101525, 0.14189705],
#        [5.418201  , 5.70526075],
#        [5.41377483, 1.12911668],
#        [5.42012266, 5.78490505],
#        [5.41752639, 5.39288108],
#        [5.4200222 , 5.38688548],
#        [5.41840883, 0.25672028],
#        [5.41807011, 5.42693199],
#        [5.41811044, 2.9010306 ],
#        [5.41964109, 5.44866602],
#        [5.42004938, 5.45025745],
#        [5.41573912, 5.45301237],
#        [5.41862529, 5.45670515],
#        [5.41819439, 5.39396744],
#        [5.41820453, 5.25672641],
#        [5.41815442, 5.51448369],
#        [5.41815195, 5.3543767 ],
#        [5.418166  , 5.33086743],
#        [5.41828239, 3.76424145],
#        [3.70191613, 3.69174743],
#        [3.78320714, 3.91696985],
#        [3.98346404, 3.17390612],
#        [3.98344707, 3.97343711],
#        [3.98328241, 3.88310236],
#        [3.89251953, 3.69827391],
#        [3.77914145, 3.69898418],
#        [3.74380007, 3.91573045],
#        [3.59107084, 3.41696788],
#        [3.58905047, 1.47054185],
#        [3.59071735, 3.47055958],
#        [3.58277213, 3.42613535],
#        [3.5887069 , 4.52221918],
#        [3.59051576, 5.622924  ],
#        [3.59036644, 3.73559547],
#        [3.58911263, 3.53094705],
#        [3.5904734 , 1.53440463],
#        [3.58927356, 0.98318102],
#        [3.58814791, 3.50849061],
#        [3.58967059, 3.93928354],
#        [3.590316  , 3.31402055],
#        [3.58889295, 3.15710927],
#        [3.59022638, 3.09667906],
#        [3.58932649, 1.43488722],
#        [3.58760152, 1.13004548],
#        [3.59493135, 0.81371677],
#        [3.58817094, 2.65566461],
#        [3.37847339, 2.34552869],
#        [1.66593567, 2.09064348],
#        [1.66732458, 1.60326011],
#        [1.65807404, 1.59636748],
#        [1.66511028, 1.58973314],
#        [1.62805233, 1.59580235],
#        [1.53342534, 6.24726327],
#        [1.50484193, 1.44983176],
#        [1.50481936, 1.28253855],
#        [1.38157831, 0.81547618],
#        [5.98986269, 1.50630033],
#        [5.9179547 , 5.61383708],
#        [5.91212701, 2.15715013],
#        [5.21122611, 5.41589468],
#        [4.07744343, 4.04009138],
#        [4.21456665, 4.17929241],
#        [4.22614635, 3.63354787],
#        [4.22132208, 4.17793219],
#        [4.18666477, 4.1771678 ],
#        [3.96464009, 3.91783976],
#        [4.04437741, 0.90771591],
#        [4.10454771, 4.34836356],
#        [4.10531652, 4.55750912],
#        [4.10381861, 4.94717991],
#        [4.1037269 , 5.68858412],
#        [4.10531876, 4.20060289],
#        [4.10066202, 4.21495944],
#        [4.10760943, 4.21846031],
#        [4.10578387, 4.1179405 ],
#        [4.09651903, 4.23218285],
#        [4.10455955, 4.23448669],
#        [4.1042366 , 4.1347148 ],
#        [4.09837882, 6.10409053],
#        [4.19664132, 4.61935077],
#        [4.19840609, 1.12039106],
#        [4.19721751, 1.08685313],
#        [1.23021609, 1.23039253],
#        [1.09390446, 1.05572749],
#        [1.03182645, 1.03595917],
#        [1.05842022, 1.12716239],
#        [1.06844688, 1.0163835 ],
#        [0.01516671, 5.99372275],
#        [5.84610243, 6.03117347],
#        [5.84604566, 5.83876474],
#        [5.84599327, 5.41384119],
#        [5.84617635, 5.06709463],
#        [5.84605859, 5.83637722],
#        [5.79350099, 5.65829581],
#        [5.63770886, 2.87318828],
#        [5.63877002, 5.42265335],
#        [5.8262187 , 6.15088496],
#        [5.73354616, 5.7092566 ],
#        [5.59806819, 5.61681437],
#        [5.68627425, 6.04233885],
#        [5.68211155, 0.5880026 ],
#        [5.68476641, 0.07017826],
#        [5.6872673 , 1.51326825],
#        [5.68943564, 5.86368487],
#        [5.6887103 , 0.18146278],
#        [5.76161342, 0.21530607],
#        [5.84695492, 5.34848282],
#        [5.84698355, 5.94240956],
#        [5.84780209, 5.86079867],
#        [5.84398935, 2.14694763],
#        [5.84792763, 5.50728732],
#        [5.75833076, 5.37673758],
#        [5.75311312, 5.87592289],
#        [5.75105291, 2.10612174],
#        [5.75296953, 2.22630887],
#        [5.75298495, 5.52723165],
#        [5.7531821 , 3.25108211],
#        [5.75353424, 5.74097494],
#        [5.75280851, 5.73786176],
#        [5.75437274, 6.12918257],
#        [5.80277949, 0.48239189],
#        [5.88417965, 0.21257644],
#        [6.23477095, 0.84555067],
#        [0.22936256, 1.45388037],
#        [0.71010652, 0.87854936],
#        [1.60325636, 1.92659464],
#        [2.12639377, 2.63942656],
#        [2.4574152 , 2.42397298],
#        [2.6900714 , 2.65284333],
#        [2.69086144, 2.61326919],
#        [2.5769848 , 2.4530549 ],
#        [2.57484928, 2.62702867],
#        [2.73716634, 2.8809527 ],
#        [2.73624974, 2.75937255],
#        [2.73629379, 2.72723825],
#        [2.73612654, 2.74904914],
#        [2.73634569, 3.39934127],
#        [2.73627161, 2.72524636],
#        [2.73632059, 2.14985915]])

# %%
dfa = pd.DataFrame(angles, columns=['Observed', 'Predicted'])
sns.jointplot(x='Observed',y='Predicted',data=dfa,kind='kde');

# %%
heatmap, xedges, yedges = np.histogram2d(angles[:,0], angles[:,1], bins=30)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower',cmap='afmhot')
plt.ylabel('Predicted Heading Direction')
plt.xlabel('Observed Heading Direction')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Testing Area
#
# Sandbox for developing new features

# %%
def firing_rate_map(arr,bin_size):
    fr_dict = {}
    for ybin in range(0,int(arr[:,1].max()+1),bin_size):
        fr_dict[ybin] = {}
        for xbin in range(0,int(arr[:,0].max()+1),bin_size):
            times = []
            fr_dict[ybin][xbin] = []
            for spike in arr:
                if (xbin <= spike[0] <= xbin+bin_size) and (ybin <= spike[1] <= ybin+bin_size):
                    times.append(spike[2]/1000)   
            
#             # Group spikes by differences > 1000 ms
#             split_inds = []
#             times = np.unique(np.sort(times)) # Cases of same time?
#             for i in range(len(times)):
#                 try:
#                     if times[i+1]-times[i]>1:
#                         split_inds.append(i+1)
#                 except:
#                     pass
#             spike_groups = np.split(times,np.unique(split_inds))
            
#             # Find firing rate of each group by dividing the total count/duration
#             rates = []
#             for i in spike_groups:
#                 try:
#                     a = len(i)
#                     b = max(i)-min(i)
#                     if b == 0:
#                         b = 1
#                     rates.append(a/b)
#                 except:
#                     pass
            
            fr_dict[ybin][xbin] = times
            
    return fr_dict


fr_arr = np.column_stack((XYspkT,spkT))
fr_dict = firing_rate_map(fr_arr,2)


#Rotate the dataframe 90 CCW
frm = pd.DataFrame.from_dict(fr_dict).T
fr_df = frm.reindex(index=frm.index[::-1])


plt.matshow(fr_df)


#To-do: reflect radians in bar
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-505-b7031c52e744> in <module>
#      47
#      48
# ---> 49 plt.matshow(fr_df)
#      50
#      51
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2206         ax  = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2207
# -> 2208     im = ax.matshow(A, **kwargs)
#    2209     sci(im)
#    2210
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in matshow(self, Z, **kwargs)
#    7803               'aspect': 'equal',          # (already the imshow default)
#    7804               **kwargs}
# -> 7805         im = self.imshow(Z, **kw)
#    7806         self.title.set_y(1.05)
#    7807         self.xaxis.tick_top()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     640         if (self._A.dtype != np.uint8 and
#     641                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 642             raise TypeError("Image data cannot be converted to float")
#     643
#     644         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
fr_dict

# %%
diff = np.sort(angles[:,0]-angles[:,1])
diff

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], polar=True)
theta = np.radians(np.arange(diff.min(),diff.max()+6,6))

inds = [np.where(diff<i)[0][-1] for i in np.arange(diff.min()+6,diff.max()+6,6)] #vectorize operation?
b = np.split(diff,inds)
radii = np.array([i.size for i in b])

width = np.radians(360/60)
bars = ax.bar(theta, radii, width=width, bottom=0.0)
for theta, bar in zip(theta, bars):
    bar.set_facecolor(plt.cm.hsv(theta/6.28))
    bar.set_alpha(0.5)

plt.show()

# %%
plt.hist(np.random.uniform(low=-3.14, high=3.14, size=(500,)))
# Out:
# (array([51., 44., 56., 53., 44., 54., 47., 50., 47., 54.]),
#  array([-3.12891516, -2.50511263, -1.8813101 , -1.25750758, -0.63370505,
#         -0.00990252,  0.61390001,  1.23770253,  1.86150506,  2.48530759,
#          3.10911012]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.random.rand(500)*6.28-3.14)
# Out:
# (array([55., 55., 42., 51., 40., 43., 48., 57., 50., 59.]),
#  array([-3.13940026, -2.51555509, -1.89170991, -1.26786474, -0.64401956,
#         -0.02017439,  0.60367078,  1.22751596,  1.85136113,  2.4752063 ,
#          3.09905148]),
#  <a list of 10 Patch objects>)
